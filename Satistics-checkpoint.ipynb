# %%
import pandas as pd 
df=pd.read_csv(r"C:\Users\chint\Downloads\students_data.csv")
df
# Out:
#     Name  Age      GROUP
# 0   NIHA   23       bcom
# 1  surya   24        bca
# 2   raju   35         ds
# 3   ravi   24         cs
# 4   kavs   25         ds
# 5    sri   26         cs
# 6    sai   27  fisheries
# 7  meena   32         ai
# 8   sita   12         ai

# %%
df["Age"].max()
# Out:
# 35

# %%
df["Age"].min()
# Out:
# 12

# %%
df["Age"].mean()
# Out:
# np.float64(25.333333333333332)

# %%
df["Age"].describe()
# Out:
# count     9.000000
# mean     25.333333
# std       6.403124
# min      12.000000
# 25%      24.000000
# 50%      25.000000
# 75%      27.000000
# max      35.000000
# Name: Age, dtype: float64

# %%
import pandas as pd
df[df.Age==df.Age.max()]
# Out:
#    Name  Age GROUP
# 2  raju   35    ds

# %%
df.count()
# Out:
# Name     9
# Age      9
# GROUP    9
# dtype: int64

# %%
df['GROUP'].nunique()
# Out:
# 6

# %%
df['GROUP'].unique()
# Out:
# array(['bcom', 'bca', 'ds', 'cs', 'fisheries', 'ai'], dtype=object)

# %%
df['GROUP'].value_counts()
# Out:
# GROUP
# ds           2
# cs           2
# ai           2
# bcom         1
# bca          1
# fisheries    1
# Name: count, dtype: int64

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\chint\Downloads\students_data.csv")
df
# Out:
#     Name  Age      GROUP
# 0   NIHA   23       bcom
# 1  surya   24        bca
# 2   raju   35         ds
# 3   ravi   24         cs
# 4   kavs   25         ds
# 5    sri   26         cs
# 6    sai   27  fisheries
# 7  meena   32         ai
# 8   sita   12         ai

# %%
df['GROUP']=df['GROUP'].str.upper()
df
# Out:
#     Name  Age      GROUP
# 0   NIHA   23       BCOM
# 1  surya   24        BCA
# 2   raju   35         DS
# 3   ravi   24         CS
# 4   kavs   25         DS
# 5    sri   26         CS
# 6    sai   27  FISHERIES
# 7  meena   32         AI
# 8   sita   12         AI

# %%
df['GROUP']=df['GROUP'].str.lower()
df
# Out:
#     Name  Age      GROUP
# 0   NIHA   23       bcom
# 1  surya   24        bca
# 2   raju   35         ds
# 3   ravi   24         cs
# 4   kavs   25         ds
# 5    sri   26         cs
# 6    sai   27  fisheries
# 7  meena   32         ai
# 8   sita   12         ai

# %%
df['Name'].str.lower()
# Out:
# 0     niha
# 1    surya
# 2     raju
# 3     ravi
# 4     kavs
# 5      sri
# 6      sai
# 7    meena
# 8     sita
# Name: Name, dtype: object

# %%
df['GROUP']=df['GROUP'].str.replace("fisheries","chem")
df
# Out:
#     Name  Age GROUP
# 0   NIHA   23  bcom
# 1  surya   24   bca
# 2   raju   35    ds
# 3   ravi   24    cs
# 4   kavs   25    ds
# 5    sri   26    cs
# 6    sai   27  chem
# 7  meena   32    ai
# 8   sita   12    ai

# %% [markdown]
# Concatenate DataFrames

# %%
india=pd.DataFrame({
    "city": ["Mumbai","Agra","Banglore"],
    "temp": [34,23,45]
})
india
# Out:
#        city  temp
# 0    Mumbai    34
# 1      Agra    23
# 2  Banglore    45
